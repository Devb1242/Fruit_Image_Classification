# %%
import json

# %%
# Define a dictionary to hold the nutritional content and fun facts for each fruit
fruits_nutrition = {
    "Apple Braeburn": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Crimson Snow": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Golden 1": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Goldern 2": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Goldern 3": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Granny Smith": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Pink Lady": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red 1": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red 2": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red 3": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red Delicious": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red Yellow 1": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Apple Red Yellow 2": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "107 mg",
            "Sugar": "10 g",
            "Protein": "0.3 g",
            "Vitamin C": "4.6 mg"
        },
        "Fun Facts": "Apples are a member of the rose family, just like pears and plums."
    },
    "Avocado": {
        "Nutrition": {
            "Calories": "160 kcal",
            "Total Fat": "15 g",
            "Cholesterol": "0 mg",
            "Sodium": "7 mg",
            "Potassium": "485 mg",
            "Sugar": "0.7 g",
            "Protein": "2 g",
            "Vitamin C": "10 mg"
        },
        "Fun Facts": "Avocados are actually berries."
    },
    "Banana": {
        "Nutrition": {
            "Calories": "89 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "358 mg",
            "Sugar": "12 g",
            "Protein": "1.1 g",
            "Vitamin C": "8.7 mg"
        },
        "Fun Facts": "More than 100 billion bananas are eaten every year in the world."
    },
    "Banana Lady Finger": {
        "Nutrition": {
            "Calories": "89 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "358 mg",
            "Sugar": "12 g",
            "Protein": "1.1 g",
            "Vitamin C": "8.7 mg"
        },
        "Fun Facts": "More than 100 billion bananas are eaten every year in the world."
    },
    "Banana Red": {
        "Nutrition": {
            "Calories": "89 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "358 mg",
            "Sugar": "12 g",
            "Protein": "1.1 g",
            "Vitamin C": "8.7 mg"
        },
        "Fun Facts": "More than 100 billion bananas are eaten every year in the world."
    },
    "Beetroot": {
        "Nutrition": {
            "Calories": "43 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "78 mg",
            "Potassium": "325 mg",
            "Sugar": "7 g",
            "Protein": "1.6 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Beetroots are rich in nitrates that help lower blood pressure."
    },
    "Blueberry": {
        "Nutrition": {
            "Calories": "57 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "77 mg",
            "Sugar": "10 g",
            "Protein": "0.7 g",
            "Vitamin C": "9.7 mg"
        },
        "Fun Facts": "Blueberries are one of the only natural foods that are truly blue in color."
    },
    "Cantaloupe": {
        "Nutrition": {
            "Calories": "34 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "16 mg",
            "Potassium": "267 mg",
            "Sugar": "8 g",
            "Protein": "0.8 g",
            "Vitamin C": "37 mg"
        },
        "Fun Facts": "Cantaloupes are named after the Italian papal village of Cantalupo."
    },
    "Cherry": {
        "Nutrition": {
            "Calories": "50 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "3 mg",
            "Potassium": "173 mg",
            "Sugar": "12 g",
            "Protein": "1 g",
            "Vitamin C": "7 mg"
        },
        "Fun Facts": "Cherry trees can produce fruit for up to 100 years."
    },
    "Corn": {
        "Nutrition": {
            "Calories": "86 kcal",
            "Total Fat": "1.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "15 mg",
            "Potassium": "270 mg",
            "Sugar": "3.2 g",
            "Protein": "3.2 g",
            "Vitamin C": "6.8 mg"
        },
        "Fun Facts": "Corn is used in over 4,000 everyday grocery items."
    },
    "Dates": {
        "Nutrition": {
            "Calories": "277 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "696 mg",
            "Sugar": "66 g",
            "Protein": "1.8 g",
            "Vitamin C": "0.4 mg"
        },
        "Fun Facts": "Dates can stay good for up to 8 months when stored in an airtight container."
    },
    "Grape Blue": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Grape Pink": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Grape White": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Grape White 2": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Grape White 3": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Grape White 4": {
        "Nutrition": {
            "Calories": "69 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "191 mg",
            "Sugar": "16 g",
            "Protein": "0.7 g",
            "Vitamin C": "4 mg"
        },
        "Fun Facts": "Grapes are botanically classed as berries."
    },
    "Guava": {
        "Nutrittion":{
            "Calories": "68 kcal", 
            "Total Fat": "1 g", 
            "Cholesterol": "0 mg", 
            "Sodium": "2 mg",
            "Potassium": "417 mg", 
            "Sugar": "9 g", 
            "Protein": "2.6 g", 
            "Vitamin C": "228.3 mg"
        },
        "Fun Fact": "Guava leaves are used as herbal tea and the leaf extract as a supplement."
    },
    "Kiwi": {
        "Nutrition": {
            "Calories": "61 kcal",
            "Total Fat": "0.5 g",
            "Cholesterol": "0 mg",
            "Sodium": "3 mg",
            "Potassium": "312 mg",
            "Sugar": "9 g",
            "Protein": "1.1 g",
            "Vitamin C": "92.7 mg"
        },
        "Fun Facts": "Kiwi fruit was named after the kiwi bird, an icon of New Zealand."
    },
    "Lemon": {
        "Nutrition": {
            "Calories": "29 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "138 mg",
            "Sugar": "2.5 g",
            "Protein": "1.1 g",
            "Vitamin C": "53 mg"
        },
        "Fun Facts": "Lemons are a hybrid between a sour orange and a citron."
    },
    "Lime": {
        "Nutrition": {
            "Calories": "30 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "2 mg",
            "Potassium": "102 mg",
            "Sugar": "1.7 g",
            "Protein": "0.7 g",
            "Vitamin C": "29.1 mg"
        },
        "Fun Facts": "Limes turn yellow as they ripen, but are commonly harvested green."
    },
    "Lychee": {
        "Nutrition": {
            "Calories": "66 kcal",
            "Total Fat": "0.4 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "171 mg",
            "Sugar": "15 g",
            "Protein": "0.8 g",
            "Vitamin C": "71.5 mg"
        },
        "Fun Facts": "Lychee fruits have a history of cultivation going back as far as 2000 BC."
    },
    'Mango': {
        'Nutrition': {
            'Calories': '60 kcal',
            'Total Fat': '0.4 g',
            'Cholesterol': '0 mg',
            'Sodium': '1 mg',
            'Potassium': '168 mg',
            'Sugar': '14 g',
            'Protein': '0.8 g',
            'Vitamin C': '36.4 mg'
        },
        'Fun Facts': 'Mango trees can grow as tall as 100 feet.'
    },
    'Mango Red': {
        'Nutrition': {
            'Calories': '60 kcal',
            'Total Fat': '0.4 g',
            'Cholesterol': '0 mg',
            'Sodium': '1 mg',
            'Potassium': '168 mg',
            'Sugar': '14 g',
            'Protein': '0.8 g',
            'Vitamin C': '36.4 mg'
        },
        'Fun Facts': 'Mango trees can grow as tall as 100 feet.'
    },
    'Orange': {
        'Nutrition': {
            'Calories': '47 kcal',
            'Total Fat': '0.1 g',
            'Cholesterol': '0 mg',
            'Sodium': '0 mg',
            'Potassium': '181 mg',
            'Sugar': '9 g',
            'Protein': '0.9 g',
            'Vitamin C': '53.2 mg'
        },
        'Fun Facts': 'Brazil is the largest producer of oranges in the world.'
    },
    "Papaya": {
        "Nutrition": {
            "Calories": "43 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "8 mg",
            "Potassium": "182 mg",
            "Sugar": "7.8 g",
            "Protein": "0.5 g",
            "Vitamin C": "60.9 mg"
        },
        "Fun Facts": "Papayas contain an enzyme called papain that aids digestion."
    },
    "Passion Fruit": {
        "Nutrition": {
            "Calories": "97 kcal",
            "Total Fat": "0.7 g",
            "Cholesterol": "0 mg",
            "Sodium": "28 mg",
            "Potassium": "348 mg",
            "Sugar": "11 g",
            "Protein": "2.2 g",
            "Vitamin C": "30 mg"
        },
        "Fun Facts": "The passion fruit flower is a national flower of Paraguay."
    },
    "Peach": {
        "Nutrition": {
            "Calories": "39 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "0 mg",
            "Potassium": "190 mg",
            "Sugar": "8.4 g",
            "Protein": "0.9 g",
            "Vitamin C": "6.6 mg"
        },
        "Fun Facts": "There are over 700 varieties of peaches."
    },
    "Pear": {
        "Nutrition": {
            "Calories": "57 kcal",
            "Total Fat": "0.1 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "116 mg",
            "Sugar": "9.8 g",
            "Protein": "0.4 g",
            "Vitamin C": "4.3 mg"
        },
        "Fun Facts": "Pears ripen from the inside out."
    },
    "Pineapple": {
        "Nutrition": {
            "Calories": "50 kcal",
            "Total Fat": "0.1 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "109 mg",
            "Sugar": "10 g",
            "Protein": "0.5 g",
            "Vitamin C": "47.8 mg"
        },
        "Fun Facts": "Pineapples take about two years to grow."
    },
    "Pineapple Mini": {
        "Nutrition": {
            "Calories": "50 kcal",
            "Total Fat": "0.1 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "109 mg",
            "Sugar": "10 g",
            "Protein": "0.5 g",
            "Vitamin C": "47.8 mg"
        },
        "Fun Facts": "Pineapples take about two years to grow."
    },
    "Plum": {
        "Nutrition": {
            "Calories": "46 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "0 mg",
            "Potassium": "157 mg",
            "Sugar": "10 g",
            "Protein": "0.7 g",
            "Vitamin C": "9.5 mg"
        },
        "Fun Facts": "There are over 2,000 varieties of plums worldwide."
    },
    "Pomegranate": {
        "Nutrition": {
            "Calories": "83 kcal",
            "Total Fat": "1.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "3 mg",
            "Potassium": "236 mg",
            "Sugar": "14 g",
            "Protein": "1.7 g",
            "Vitamin C": "10.2 mg"
        },
        "Fun Facts": "Pomegranates can have up to 1,400 seeds inside them."
    },
    "Raspberry": {
        "Nutrition": {
            "Calories": "52 kcal",
            "Total Fat": "0.7 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "151 mg",
            "Sugar": "4.4 g",
            "Protein": "1.2 g",
            "Vitamin C": "26.2 mg"
        },
        "Fun Facts": "Raspberries are a member of the rose family."
    },
    "Strawberry": {
        "Nutrition": {
            "Calories": "32 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "153 mg",
            "Sugar": "4.9 g",
            "Protein": "0.7 g",
            "Vitamin C": "58.8 mg"
        },
        "Fun Facts": "Strawberries are the only fruit with seeds on the outside."
    },
    "Strawberry Wedge": {
        "Nutrition": {
            "Calories": "32 kcal",
            "Total Fat": "0.3 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "153 mg",
            "Sugar": "4.9 g",
            "Protein": "0.7 g",
            "Vitamin C": "58.8 mg"
        },
        "Fun Facts": "Strawberries are the only fruit with seeds on the outside."
    },
    "Tomato": {
        "Nutrition": {
            "Calories": "18 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "5 mg",
            "Potassium": "237 mg",
            "Sugar": "2.6 g",
            "Protein": "0.9 g",
            "Vitamin C": "13.7 mg"
        },
        "Fun Facts": "Tomatoes are scientifically a fruit, but legally vegetables."
    },
    "Watermelon": {
        "Nutrition": {
            "Calories": "30 kcal",
            "Total Fat": "0.2 g",
            "Cholesterol": "0 mg",
            "Sodium": "1 mg",
            "Potassium": "112 mg",
            "Sugar": "6 g",
            "Protein": "0.6 g",
            "Vitamin C": "8.1 mg"
        },
        "Fun Facts": "Watermelons are 92% water."
    }
   
}

fruits_nutrition
# Out:
# {'Apple Braeburn': {'Nutrition': {'Calories': '52 kcal',
#    'Total Fat': '0.2 g',
#    'Cholesterol': '0 mg',
#    'Sodium': '1 mg',
#    'Potassium': '107 mg',
#    'Sugar': '10 g',
#    'Protein': '0.3 g',
#    'Vitamin C': '4.6 mg'},
#   'Fun Facts': 'Apples are a member of the rose family, just like pears and plums.'},
#  'Apple Crimson Snow': {'Nutrition': {'Calories': '52 kcal',
#    'Total Fat': '0.2 g',
#    'Cholesterol': '0 mg',
#    'Sodium': '1 mg',
#    'Potassium': '107 mg',
#    'Sugar': '10 g',
#    'Protein': '0.3 g',
#    'Vitamin C': '4.6 mg'},
#   'Fun Facts': 'Apples are a member of the rose family, just like pears and plums.'},
#  'Apple Golden 1': {'Nutrition': {'Calories': '52 kcal',
#    'Total Fat': '0.2 g',
#    'Cholesterol': '0 mg',
#    'Sodium': '1 mg',
#    'Potassium': '107 mg',
#    'Sugar': '10 g',
#    'Protein': '0.3 g',
#    'Vitamin C': '4.6 mg'},
#   'Fun Facts': 'Apples are a member of the rose family, just like pears and plums.'},
# ...

# %%
with open("fruits_nutrition.json", "w") as outfile: 
    json.dump(fruits_nutrition, outfile)
